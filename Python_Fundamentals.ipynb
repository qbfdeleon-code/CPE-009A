# %% [markdown]
# <a href="https://colab.research.google.com/github/qbfdeleon-code/CPE-009A/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Indentation

# %%
if 5>2:
  print ("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# Python Comments

# %%
#This is a comment
print("Hello, world")
# Out:
# Hello, world

# %% [markdown]
# Pyhton Variable

# %%
x=1
a,b=0, -1
a,b,c=0,-1,2

#Others:
b ="Sally" #This is a type of string
print(b)
# Out:
# Sally

# %% [markdown]
# Casting

# %%
b="sally"#This is a type of string
b=int(4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type() Function

# %%
x=5
y="John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# "Double quotes" or 'Single quote'

# %%
y="John"
y='John'

# %% [markdown]
# Case sensitive

# %%
a=4
A="Sally"
#A will not overite a

# %% [markdown]
# Multiple Variables

# %%
x,y,z="one","two","three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One Value to Multiple Variables

# %%
x=y=z="four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
x="enjoying"
print("Python programming is "+x)

#Other way:
x="Python is "
y="enjoying"
z=x+y
print(z)
# Out:
# Python programming is enjoying
# Python is enjoying

# %% [markdown]
# Arithmetic Operations

# %%
x+=3
x=x+3

x-=3
x=x-3


x*=3
x=x*3

x/=3
x=x/3

x%=3
x=x%3

x//=3
x=x//3

x**=3
x=x**3

x&=3
x=x&3

x|=3
x=x|3

x^=3
x=x^3

x>>=3
x=x>>3

x<<=3
x=x<<3

# %% [markdown]
# Comparison Operators

# %%
t=1
u=2

t==u
t!=u
t>u
t<u
t>=u
t<=u
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
t=3
u=7

t<5 and u<10
t>5 or u<4
not(t>3 or u>3)
not(t==1 and u>5)
# Out:
# True

# %% [markdown]
# Identity Operators

# %%
t is u
t is not u
# Out:
# True

# %% [markdown]
# Bitwise Operators

# %%
v=2

v<<1
v<<2
1&2
15&15
# Out:
# 15
