# %% [markdown]
# <a href="https://colab.research.google.com/github/qbfdeleon-code/CPE-009A/blob/main/Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#23

i= 0
while i < 5:
  i += 1
  print ('*' * i)
if i == 5:
  for i in range (4,0,-1):
    print ('*' * i)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
#24
#Write a function that checks if a string of parentheses (), brackets [], and braces {} is balanced.

def check_balance(string):
 myString = {'(': ')', '[': ']', '{': '}'}
 if len(string) % 2 != 0:
  return False
 elif len(string) == 0:
  return True

 Ex_1 = '{[()]}'
 Ex_2 = '([)]'
 Ex_3 = '((()))'

 print(check_balance(Ex_1))
 print(check_balance(Ex_2))
 print(check_balance(Ex_3))
