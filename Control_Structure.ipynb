# %% [markdown]
# <a href="https://colab.research.google.com/github/qbfdeleon-code/CPE-009A/blob/main/Control_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if Statement

# %%
a=12
b=100
if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# Elif Statement

# %%
a=12
b=12
if b>a:
  print("b is greater than a")
elif a==b:
    print("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# Else Statements

# %%
a=200
b=33
if b>a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand If Statement

# %%
if a>b: print ("a is greater than b")

# %% [markdown]
# Short Hand If..Else Stement

# %%
a=2
b=330
print("A") if a>b else print("B")
# Out:
# B

# %% [markdown]
# And-both conditions are true

# %%
a=200
b=33
c=500
if a>b and c>a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# Oraat least one of the conditions is true

# %%
a=200
b=33
c=500
if(a>b or a>c):
  print("At least one condition is True")
# Out:
# At least one condition is True

# %% [markdown]
# Nested if

# %%
x=41

if x>10:
  print("Above ten,")
  if x>20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
# Create a python program that will display above 10, above 20, above 30, above 40

print("Enter a number")
x = int(input())  #user input
if x>10:
  print("Above ten,")
  if x>20:
    print("and also above 20")
    if x>30:
      print ("and also above 30")
      if x>40:
        print("and also above 40")
        if x>50:
          print("and also above 50")
        else:
          print("below 50")
      else:
        print("below 40")
    else:
      print("below 30")
  else:
    print("below 20")
else:
  print("below 10")
# Out:
# Enter a number
# 41
# Above ten,
# and also above 20
# and also above 30
# and also above 40
# below 50

# %% [markdown]
# 1. (+2)

# %%
print("Enter a number")
x=int(input())

if x>18:
  print("You are qualified to vote.")

elif x==18:
  print("You are qualified to vote.")

else:
  print("You are not 18 above, you are not qualified to vote.")
# Out:
# Enter a number
# 19
# You are qualified to vote.

# %% [markdown]
# 2.

# %%
print("Enter an integer: ")
a=int(input())

if a<1:
  print(a, "is negative")

elif a==0:
  print(a, "is zero")

else:
  print(a, "is positive")
# Out:
# Enter an integer:
# -124
# -124 is negative

# %% [markdown]
# 3.

# %%
grade=float(input("Enter student grade: "))

if grade>=75:
  print("Congrats! You passed.")

elif grade>=74:
  print("You need to remediate.")

elif grade<1:
  print("Invalid grade.")

else:
  print("You failed.")
# Out:
# Enter student grade: -78
# Invalid grade.
