# %% [markdown]
# <a href="https://colab.research.google.com/github/qbfdeleon-code/CPE-009A/blob/main/Hands_on_Activity_1_1_Literals%2C_Operators%2C_and_Variables_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assigning variables of different data types in Python

# %%
value=5
print(value)
# Out:
# 5

# %%
type(value)
# Out:
# int

# %%
value=5.0
print(value)
# Out:
# 5.0

# %%
type(value)
# Out:
# float

# %% [markdown]
# a.

# %%
value=2+3j
print(value)
# Out:
# (2+3j)

# %%
type(value)
# Out:
# complex

# %% [markdown]
# b.

# %%
value = 'Hello World'
print(value)
# Out:
# Hello World

# %%
type(value)
# Out:
# str

# %% [markdown]
# c.

# %%
value = "Hello World"
print(value)
# Out:
# Hello World

# %%
type(value)
# Out:
# str

# %% [markdown]
# d.

# %%
value=True
print(value)
# Out:
# True

# %%
type(value)
# Out:
# bool

# %% [markdown]
# e.

# %%
value=False
print(value)
# Out:
# False

# %%
type(value)
# Out:
# bool

# %% [markdown]
# f.

# %%
value=[1,2,3,4,5]
print(value)
# Out:
# [1, 2, 3, 4, 5]

# %%
type(value)
# Out:
# list

# %% [markdown]
# g.

# %%
value=(1,2,3,4,5)
print(value)
# Out:
# (1, 2, 3, 4, 5)

# %%
type(value)
# Out:
# tuple

# %% [markdown]
# h.

# %%
value={'name': 'Benj Federic De Leon'}
print(value)
# Out:
# {'name': 'Benj Federic De Leon'}

# %%
type(value)
# Out:
# dict

# %% [markdown]
# i.

# %%
value=None
print(value)
# Out:
# None

# %%
type(value)
# Out:
# NoneType

# %%
value = 5

# %%
value2 = -6

# %% [markdown]
# Performing Operation With Python

# %%
print(value+value2)
# Out:
# -1

# %% [markdown]
# a.

# %%
value, value2=5.0,6

# %%
print(value+value2)
# Out:
# 11.0

# %% [markdown]
# b.

# %%
value, value2=-5, 6.1

# %%
print(value+value2)
# Out:
# 1.0999999999999996

# %% [markdown]
# c.

# %%
value, value2="Hello ", 'world'

# %%
print(value+value2)
# Out:
# Hello world

# %% [markdown]
# d.

# %%
value, value2=[1,2,3], [4,5,6]

# %%
print(value+value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# e.

# %%
value, value2=(1,2,3), (4,5,6)

# %%
print(value+value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# f.

# %%
value, value2={"name":"Benj Federic De Leon"}, {"age":19}

# %%
print(value,value2)
# Out:
# {'name': 'Benj Federic De Leon'} {'age': 19}

# %%
value, value2 = 30, 4

# %%
print(value*value2)
# Out:
# 120

# %%
print(value2**2)
# Out:
# 16

# %%
print(value2**3)
# Out:
# 64

# %%
print(value*value2+value2**2+1)
# Out:
# 137

# %%
print(value/value2)
# Out:
# 7.5

# %%
print(value%value2)
# Out:
# 2

# %% [markdown]
# Assigning Input Data to a Variable Finding a person’s BMI (metric)

# %%
name=input("Name:")
weight=input("Weight:")
height=float(input("Height:"))
bmi=float(weight)/float(height)**2
print(bmi)
# Out:
# Name:Benj Federic De Leon
# Weight:60
# Height:1.8
# 18.51851851851852

# %% [markdown]
# Supplementary Activity
