# %% [markdown]
# <a href="https://colab.research.google.com/github/qbfdeleon-code/CPE-009A/blob/main/Hands_on_Activity_3_1_Sequence_and_Mapping_Types_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: De Leon, Benj Federic C.
#
#
# Section: CPE12S2
#
#
# Date performed: February 26, 2026
#
# ---

# %% [markdown]
# 1.

# %%
numberlist = [5,4,2,1,3]

# %% [markdown]
# 2.

# %%
#a.
print(len(numberlist))
# Out:
# 5

# %%
#b.
print(numberlist[0])
# Out:
# 5

# %%
#c.
print(numberlist[1])
# Out:
# 4

# %%
#d.
print(numberlist[2])
# Out:
# 2

# %%
#e.
print(numberlist[3])
# Out:
# 1

# %%
#f.
print(numberlist[4])
# Out:
# 3

# %%
#g.
print(numberlist[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-834/2677799133.py in <cell line: 0>()
#       1 #g.
# ----> 2 print(numberlist[5])
#
# IndexError: list index out of range

# %%
#h.
print(numberlist[-1])
# Out:
# 3

# %%
#g.
print(numberlist[-2])
# Out:
# 1

# %%
#j.
print(numberlist[-3])
# Out:
# 2

# %%
#k.
print(numberlist[-4])
# Out:
# 4

# %%
#l.
print(numberlist[-5])
# Out:
# 5

# %%
#m.
print(numberlist[-6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-834/1382137861.py in <cell line: 0>()
#       1 #m.
# ----> 2 print(numberlist[-6])
#
# IndexError: list index out of range

# %% [markdown]
# 3. I observed that all

# %% [markdown]
# 4.

# %%
itemlist = [1,-2.0,[1,2,3],”Word”]
